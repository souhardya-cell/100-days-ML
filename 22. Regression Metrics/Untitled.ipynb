# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %% [markdown]
# <h2>Calculating Regression Metrics</h2>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred=lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# MAE 0.2884710931878175
# MSE 0.12129235313495527
# RMSE 0.34827051717731616

# %%
print("R2 Score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 Score 0.780730147510384

# %%
X_test.shape
# Out:
# (40, 1)

# %%
# Adjusted R2 score
1-((1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
# Out:
# 0.7749598882343415

# %% [markdown]
# <h3>Adding an irrelevant feature</h3>

# %%
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.518824     3.26
# 1  5.12        0.956410     1.98
# 2  7.82        0.541753     3.25
# 3  7.42        0.530401     3.67
# 4  6.94        0.315712     3.57

# %%
plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel('random_feature')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.7805396094619472

# %%
# Adjusted R2 score
1-((1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
# Out:
# 0.7686768856490795

# %% [markdown]
# <h5>So we see that on adding an irrelevant feature, the r2 score almost remained same but the adjusted r2 decreased. This is why adjusted r2 is important.</h5>

# %% [markdown]
# <h3>Adding a relevant feature</h3>

# %%
new_df2 = df.copy()

new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]

# %%
new_df2.head()
# Out:
#    cgpa    iq  package
# 0  6.89  4.36     3.26
# 1  5.12  2.28     1.98
# 2  7.82  2.55     3.25
# 3  7.42  2.57     3.67
# 4  6.94  2.87     3.57

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('iq')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.8063091137693101

# %%
# Adjusted R2 score
1-((1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1))
# Out:
# 0.7958393361352187

# %% [markdown]
# <h5>Therefore on adding a relevant feature, both the r2 score and the adjusted r2 score increases which is what we expect and need from the model.</h5>
