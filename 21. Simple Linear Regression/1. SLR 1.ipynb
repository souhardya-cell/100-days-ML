# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.780730147510384

# %% [markdown]
# <h4>VISUALISING THE LINEAR REGRESSION LINE</h4>

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,lr.predict(x_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %% [markdown]
# <h5>plots the actual CGPA-vs-package data and draws the straight line that your Linear Regression model learned to predict package from CGPA.</h5>

# %% [markdown]
# <h4>Seeing m and b Values</h4>

# %%
#m value
m=lr.coef_
m
# Out:
# array([0.55795197])

# %%
#b value
b=lr.intercept_
b
# Out:
# np.float64(-0.8961119222429144)

# %%
#predicting the first test data
print(lr.predict(x_test.iloc[0].values.reshape(1,1)))
# Out:
# [3.89111601]
# C:\Users\souha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
