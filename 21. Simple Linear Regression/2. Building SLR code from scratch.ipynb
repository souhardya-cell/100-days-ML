# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x=df.iloc[:,0]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.shape
# Out:
# (160,)

# %% [markdown]
# <h2>Building Simple Linear Regression from Scratch</h2>

# %%
class myLR:
    def __init__(self):
        self.m=None
        self.b=None

    def fit(self,x_train,y_train):
        num=0
        den=0

        for i in range(x_train.shape[0]):
            num+=((x_train.iloc[i] - x_train.mean())*(y_train.iloc[i] - y_train.mean()))
            den+=((x_train.iloc[i]-x_train.mean())*(x_train.iloc[i]-x_train.mean()))

        self.m=num/den
        self.b=y_train.mean()-(self.m * x_train.mean())
        print(self.m)
        print(self.b)

    def predict(self,x_test):
        print(x_test)
        print (self.m*x_test+self.b)

# %%
lr=myLR()
lr.fit(x_train,y_train)
# Out:
# 0.5579519734250721
# -0.8961119222429152

# %% [markdown]
# <h5>These are the same values that were generated for m & b respectively by using the scikit learn class for Simple Linear Regression in the Jupyter Notebook SLR 1. Therefore, our scratch SLR code is working.</h5>

# %%
lr.predict(x_test.iloc[0])
# Out:
# 8.58
# 3.891116009744203

# %% [markdown]
# <h5>This matches too.</h5>
